# %%
#Data Manipulation libraries 
import numpy as np
import pandas as pd

#Data Visualisation libraries
import matplotlib.pyplot as plt
from matplotlib import rcParams
import seaborn as sns 

#Applying cool styles 
plt.style.use("ggplot")
rcParams['figure.figsize']=(12, 6)


# from sklearn.model_selection import train_test_split
# from sklearn import linear_model

# %%
df = pd.read_csv("datasets/animes.csv")
df.head()
# Out:
#      uid                             title  \
# 0  28891           Haikyuu!! Second Season
# 1  23273           Shigatsu wa Kimi no Uso
# 2  34599                     Made in Abyss
# 3   5114  Fullmetal Alchemist: Brotherhood
# 4  31758  Kizumonogatari III: Reiketsu-hen
#
#                                             synopsis  \
# 0  Following their participation at the Inter-Hig...
# 1  Music accompanies the path of the human metron...
# 2  The Abyss—a gaping chasm stretching down into ...
# 3  "In order for something to be obtained, someth...
# 4  After helping revive the legendary vampire Kis...
#
#                                                genre  \
# 0  ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1  ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2  ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3  ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4   ['Action', 'Mystery', 'Supernatural', 'Vampire']
#
#                           aired  episodes  members  popularity  ranked  score  \
# 0   Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0   8.82
# 1  Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0   8.83
# 2   Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0   8.83
# 3    Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0   9.23
# 4                   Jan 6, 2017       1.0   214621         502    22.0   8.83
#
#                                              img_url  \
# 0  https://cdn.myanimelist.net/images/anime/9/766...
# 1  https://cdn.myanimelist.net/images/anime/3/671...
# 2  https://cdn.myanimelist.net/images/anime/6/867...
# 3  https://cdn.myanimelist.net/images/anime/1223/...
# 4  https://cdn.myanimelist.net/images/anime/3/815...
#
#                                                 link
# 0  https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1  https://myanimelist.net/anime/23273/Shigatsu_w...
# 2  https://myanimelist.net/anime/34599/Made_in_Abyss
# 3  https://myanimelist.net/anime/5114/Fullmetal_A...
# 4  https://myanimelist.net/anime/31758/Kizumonoga...

# %%
df.tail()
# Out:
#          uid                                        title  \
# 19306  32979                                Flip Flappers
# 19307    123                                Fushigi Yuugi
# 19308   1281                             Gakkou no Kaidan
# 19309    450  InuYasha Movie 2: Kagami no Naka no Mugenjo
# 19310     87     Mobile Suit Gundam: Char's Counterattack
#
#                                                 synopsis  \
# 19306  Cocona is an average middle schooler living wi...
# 19307  While visiting the National Library, junior-hi...
# 19308  Years ago, all of the ghosts in a haunted scho...
# 19309  Inuyasha and company have finally destroyed Na...
# 19310  The year is Universal Century 0093. Char Aznab...
#
#                                                    genre  \
# 19306         ['Sci-Fi', 'Adventure', 'Comedy', 'Magic']
# 19307  ['Adventure', 'Fantasy', 'Magic', 'Martial Art...
# 19308              ['Mystery', 'Horror', 'Supernatural']
# 19309  ['Action', 'Adventure', 'Comedy', 'Historical'...
# 19310  ['Military', 'Sci-Fi', 'Space', 'Drama', 'Mecha']
#
#                               aired  episodes  members  popularity  ranked  \
# 19306   Oct 6, 2016 to Dec 29, 2016      13.0   134252         843  1070.0
# 19307   Apr 6, 1995 to Mar 28, 1996      52.0    84407        1292  1071.0
# 19308  Oct 22, 2000 to Mar 25, 2001      19.0    83093        1314  1073.0
# 19309                  Dec 21, 2002       1.0    71989        1469  1077.0
# 19310                  Mar 12, 1988       1.0    29248        2604  1081.0
#
#        score                                            img_url  \
# 19306   7.73  https://cdn.myanimelist.net/images/anime/4/822...
# 19307   7.73  https://cdn.myanimelist.net/images/anime/2/201...
# 19308   7.73  https://cdn.myanimelist.net/images/anime/9/183...
# 19309   7.73  https://cdn.myanimelist.net/images/anime/1162/...
# 19310   7.73  https://cdn.myanimelist.net/images/anime/1523/...
#
#                                                     link
# 19306  https://myanimelist.net/anime/32979/Flip_Flappers
# 19307    https://myanimelist.net/anime/123/Fushigi_Yuugi
# 19308  https://myanimelist.net/anime/1281/Gakkou_no_K...
# 19309  https://myanimelist.net/anime/450/InuYasha_Mov...
# 19310  https://myanimelist.net/anime/87/Mobile_Suit_G...

# %%
df.shape
# Out:
# (19311, 12)

# %%
df.describe()
# Out:
#                 uid      episodes       members    popularity        ranked  \
# count  19311.000000  18607.000000  1.931100e+04  19311.000000  16099.000000
# mean   19358.904096     11.568281  3.472609e+04   7720.830304   6866.524194
# std    14271.446515     49.063584  1.121772e+05   4676.786104   4390.018768
# min        1.000000      1.000000  2.500000e+01      1.000000      1.000000
# 25%     4833.500000      1.000000  3.880000e+02   3725.000000   2895.500000
# 50%    18327.000000      2.000000  2.389000e+03   7539.000000   6963.000000
# 75%    33896.500000     12.000000  1.450150e+04  11613.000000  10601.500000
# max    40960.000000   3057.000000  1.871043e+06  16338.000000  14675.000000
#
#               score
# count  18732.000000
# mean       6.436107
# std        1.007941
# min        1.250000
# 25%        5.770000
# 50%        6.410000
# 75%        7.150000
# max        9.230000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18607 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   ranked      16099 non-null  float64
#  9   score       18732 non-null  float64
#  10  img_url     19131 non-null  object
#  11  link        19311 non-null  object
# dtypes: float64(3), int64(3), object(6)
# memory usage: 1.8+ MB

# %%
# Check if there are any useless or redundant variables.
# Are there any duplicate rows.
# Does the nomenclatue makes any sense.
# Are there any new variables we want to create.

# %%
# Check if there are any useless or redundant variables.

# We can remove img_url & link columns. 

del df['img_url']
del df['link']

#df.drop(['img_url','link'], axis = 1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18607 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   ranked      16099 non-null  float64
#  9   score       18732 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
# Are there any duplicate rows.
#df.duplicated().sum()

# %%
#df.ranked.duplicated()

# %%
#df.loc[df.duplicated(keep = False), :]

#df.loc[df.duplicated(), :]

# %%
# Are there any duplicate rows.
df.drop_duplicates(subset='uid')
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   uid         19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18607 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   ranked      16099 non-null  float64
#  9   score       18732 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.5+ MB
# (19311, 10)

# %%
# Does the nomenclatue makes any sense.

df.rename(columns={"uid": "Anime_ID"}, inplace=True)
df.rename(columns={"ranked": "Rank"}, inplace=True)
df.rename(columns={"score": "Rating"}, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19311 entries, 0 to 19310
# Data columns (total 10 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Anime_ID    19311 non-null  int64
#  1   title       19311 non-null  object
#  2   synopsis    18336 non-null  object
#  3   genre       19311 non-null  object
#  4   aired       19311 non-null  object
#  5   episodes    18607 non-null  float64
#  6   members     19311 non-null  int64
#  7   popularity  19311 non-null  int64
#  8   Rank        16099 non-null  float64
#  9   Rating      18732 non-null  float64
# dtypes: float64(3), int64(3), object(4)
# memory usage: 1.5+ MB

# %%
# Are there any new variables we want to create.

# %%
#plots every pair integer columns.
sns.pairplot(df)

# %%
coremat=df.corr()
# Out:
# C:\Users\lucky\AppData\Local\Temp\ipykernel_8176\3359615107.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   coremat=df.corr()

# %%
coremat
# Out:
#             Anime_ID  episodes   members  popularity      Rank    Rating
# Anime_ID    1.000000 -0.076387 -0.065095    0.342304  0.368896 -0.200402
# episodes   -0.076387  1.000000  0.089629   -0.037989 -0.059550  0.075963
# members    -0.065095  0.089629  1.000000   -0.448320 -0.408786  0.426010
# popularity  0.342304 -0.037989 -0.448320    1.000000  0.854241 -0.694138
# Rank        0.368896 -0.059550 -0.408786    0.854241  1.000000 -0.834105
# Rating     -0.200402  0.075963  0.426010   -0.694138 -0.834105  1.000000

# %%
coremat.columns
# Out:
# Index(['Anime_ID', 'episodes', 'members', 'popularity', 'Rank', 'Rating'], dtype='object')

# %%
corrmat = df.corr()
hm = sns.heatmap(corrmat, 
                 cbar=True, 
                 annot=True, 
                 square=True, 
                 fmt='.2f', 
                 annot_kws={'size': 10}, 
                 yticklabels=coremat.columns, 
                 xticklabels=coremat.columns, 
                 cmap="Spectral_r")
plt.show()
# Out:
# C:\Users\lucky\AppData\Local\Temp\ipykernel_8176\119785578.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmat = df.corr()

# %%
df.isnull().sum()
# Out:
# Anime_ID         0
# title            0
# synopsis       975
# genre            0
# aired            0
# episodes       704
# members          0
# popularity       0
# Rank          3212
# Rating         579
# dtype: int64

# %% [markdown]
# ### KNN Implementation using Euclidean Distance

# %%
def custom_KNN(metrics, data):
    
    e_distances    = []
    length           = len(data.Anime_ID)
    
    

    genre            = data["genre"].values
    in_genres      = len(metrics[0])
    
    anime_ids             = data["Anime_ID"].values
    titles           = data["title"].values
    
    popularities       = data["popularity"].values
    episodes         = data["episodes"].values
    ranks             = data["Rank"].values
    
    for i in range(length):
        genre_cnt  = 0
        temp_popularity         = 0
        temp_episodes         = 0
        temp_rank      = 1
        e_distance  = 0
        
        #checking metric genere
        for j in metrics[0]:
            if j in genre[i]:
                genre_cnt = genre_cnt + 1
        
        #checking metric popularities(if popularities is below metioned treating it as 1 else treating it as 0)
        if popularities[i] < metrics[1]:
            temp_popularity = 1
        
        #checking metric episodes(checking distance from given number of episodes to number of episodes of that anime)
        temp_episodes = episodes[i]
        
        #checing metric rank(if the anime ranks below the mentioned rank, then it is treated as 0 or else it is 1)
        if ranks[i] < metrics[3]:
            temp_rank = 0
            
        e_distance =  (((in_genres-genre_cnt)**2) + ((temp_popularity)**2) + ((metrics[2]-temp_episodes)**2) + ((temp_rank)**2))**0.5
        e_distances.append([i,anime_ids[i],titles[i],e_distance])
            
    return e_distances

# %%
def KNN(l_metrics, df, k = 10):
    
    l_e_distances = custom_KNN(l_metrics, df)
    
    l_e_distances.sort(key=lambda row: (row[3]))
    
    #print(l_e_distances)
    
    for i in range(k):
        print(l_e_distances[i][2], ' : ', l_e_distances[i][3])

# %%
#input metrics Genre, pop(above that number is liked), Episodes(episodes approx to that number), rank(below that num is liked)
input_metrics = [["Adventure", "Romance"],34,700,100]
KNN(input_metrics, df, 20)
# Out:
# Naruto: Shippuuden  :  200.00749985938026
# One Piece  :  315.00158729758806
# Kochira Katsushikaku Kameari Kouenmae Hashutsujo  :  327.00764517056786
# Bleach  :  334.004490987771
# Otogi Manga Calendar  :  388.0064432454698
# Gintama  :  499.0040079999358
# Urusei Yatsura  :  505.0009900980393
# Tennis no Ouji-sama  :  522.0047892500604
# Lupin III: Part II  :  545.0018348592967
# Saint Seiya  :  586.0017064821569
# Ookami Shounen Ken  :  614.0016286623351
# Shounen Ninja Kaze no Fujimaru  :  635.0015748011969
# Tsurupika Hagemaru-kun  :  641.0039001441411
# Porong Porong Pororo 2  :  648.0038580132066
# Rockman.EXE Stream  :  649.0015408302202
# Marvel Disk Wars: The Avengers  :  649.0038520686915
# Turn A Gundam  :  650.0007692303141
# Wu Geng Ji 2nd Season  :  658.0037993811281
# Yao Shen Ji 3rd Season  :  660.0007575753228
# Kyou kara Maou! 3rd Series  :  661.0015128575728

# %% [markdown]
# ### clustering

# %%
def kmeans_clustering(data, k = 10):
    beginner = []
    pro = []
    advanced = []
    
    titles = data["title"].values
    genre = data["genre"].values
    anime_ids = data["Anime_ID"].values
    episodes = data["episodes"].values
    ranks = data["Rank"].values
    #print(genre[:5])
    #print(anime_ids[:5])
    #print(episodes[:5])
    list_to_sort = []
    for i in range(len(anime_ids)):
        list_to_sort.append([anime_ids[i], titles[i], ranks[i], episodes[i], (genre[i])])
    
    #print(list_to_sort[:5])
    
    list_to_sort.sort(key=lambda row: (row[2]))
    
    #print(list_to_sort)
    
    """dict1 = {}
    for i in range(len(anime_ids)):
        dict1[anime_ids[i]] = [genre[i], episodes[i], ranks[i]]"""
        
    for i in list_to_sort:
        if i[2] <= 100:
            beginner.append(i[1])
        elif i[2] <= 500:
            pro.append(i[1])
        else:
            advanced.append(i[1])
    print(' Beginner animes are: ')     
    for i in range(k):
        print(beginner[i])
    print('--------------------------------------------------------')
    print(' Pro animes are: ')     
    for i in range(k):
        print(pro[i])
    print('--------------------------------------------------------')
    print(' Advanced animes are: ')     
    for i in range(k):
        print(advanced[i])

# %%
kmeans_clustering(df, 5)
# Out:
#  Beginner animes are:
# Fullmetal Alchemist: Brotherhood
# Steins;Gate
# Hunter x Hunter (2011)
# Kimi no Na wa.
# Shingeki no Kyojin Season 3 Part 2
# --------------------------------------------------------
#  Pro animes are:
# Kaze ga Tsuyoku Fuiteiru
# Shingeki no Kyojin Season 3
# Uchuu Kyoudai
# Hotarubi no Mori e
# Kenpuu Denki Berserk
# --------------------------------------------------------
#  Advanced animes are:
# Nurarihyon no Mago: Sennen Makyou
# Omae Umasou da na
# Persona 3 the Movie 4: Winter of Rebirth
# Phantom: Requiem for the Phantom
# Tamako Love Story
